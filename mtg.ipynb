# %%
from satpy import Scence
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from satpy import Scence
#
# ImportError: cannot import name 'Scence' from 'satpy' (/home/lagha/anaconda3/envs/meteo/lib/python3.12/site-packages/satpy/__init__.py)
